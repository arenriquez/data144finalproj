# %% [markdown]
# # Import Libraries and Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from scipy import stats

# %% [markdown]
# # Daniel's EDA

# %% [markdown]
# Let's first explore what the original datasets look like and their summaries.

# %%
# Display previews of datasets
math = pd.read_csv('student-mat.csv')
port = pd.read_csv('student-por.csv')
display(math.head(), port.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# ...

# %%
# Display length of math and portuguese class datasets
print("There are " + str(math.shape[0]) + " entries in the math dataset.")
print("There are " + str(port.shape[0]) + " entries in the Portuguese dataset.")
# Out:
# There are 395 entries in the math dataset.
# There are 649 entries in the Portuguese dataset.

# %%
# Combine both datasets for convenience; specify 'course' column for each dataset
# Is this useful? Not really, but it's interesting
math_copy = math.copy(); port_copy = port.copy()
math_copy['course'] = ['math' for i in np.arange(math.shape[0])]
port_copy['course'] = ['portuguese' for i in np.arange(port.shape[0])]
combined = pd.concat([math_copy, port_copy])
combined_shuffled = sklearn.utils.shuffle(combined)
combined_shuffled.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 56      GP   F   15       U     GT3       A     4     3  services  services
# 383     GP   M   18       U     LE3       T     2     2     other     other
# 268     GP   M   18       U     GT3       T     4     2    health     other
# 341     GP   F   19       U     GT3       T     4     4    health     other
# 338     GP   F   17       R     LE3       T     3     1  services     other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3      course
# 56   ...        3     2     1     1       1        0  14  15  15        math
# 383  ...        5     5     2     4       5        0  11  11  12  portuguese
# 268  ...        4     5     1     3       5       10  10   9  10        math
# 341  ...        3     4     2     3       2        2  14  13  13  portuguese
# 338  ...        1     2     1     1       3        0  18  19  19  portuguese
#
# [5 rows x 34 columns]

# %% [markdown]
# Idea 1: Predict a student's success (measured in G3) based on certain features.
#
# This is an interesting question to ask as the alcohol consumption data may indicate that higher alcohol consumption leads to decreased final grades and, thereby, less success for the student.
#
# To do this, we need to train a model that can predict a student's G3 and identify which features have the most impact on G3.
#
# Should we only look at Portuguese/math course data or combine the two? There are bound to be duplicate student entries if we were to combine the two datasets, as each dataset would contain several entries regarding the same student, albeit in different courses.
# **Later update:** We'll look at the datasets separated by math vs. Portuguese.
#
# Which features should we consider? All features and possible subsets to consider are listed below. I'll mainly be exploring the Portuguese student dataset, while Andrew explores the math student dataset.
#
# Now, let's explore the distribution of G3 (final grades) based on several different features.

# %%
# All columns in dataset as a Numpy array
columns = np.array(port.columns)
columns
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic',
#        'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3'], dtype=object)

# %%
sns.catplot(x='famsup', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on family support")
# Out:
# Text(0.5, 1.0, 'Count of Port. students pursuing a higher education based on family support')

# %% [markdown]
# # Andrew's EDA

# %%
math_data = math.copy(); port_copy1 = port.copy()

# %% [markdown]
# first will analyze math because it is a universal subject

# %%
cat =[]
num =[]
for i in math_data.columns:
    if math_data[i].dtype==object:
        cat.append(i)
    else:
        num.append(i)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(math_data[num].corr(),annot = True,cbar = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Among numerical categories, the only ones that correlate with scores are the other scores reported.

# %%
print(cat)
# Out:
# ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# %%
#f= plt.figure(figsize=(18,6))
fig, ax = plt.subplots()

sns.distplot(math_data[(math_data.paid == 'yes')]["G3"],ax=ax, label="paid")
sns.distplot(math_data[(math_data.paid == 'no')]['G3'],ax=ax, label="no paid")

plt.legend()
plt.title('Distribution of grades vs paid classes')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of grades vs paid classes')

# %%
fig, ax = plt.subplots()

sns.distplot(math_data[(math_data.higher == 'yes')]["G3"],ax=ax, label="motivated")
sns.distplot(math_data[(math_data.higher == 'no')]['G3'],ax=ax, label="unmotivated")

plt.legend()
plt.title('Distribution of grades vs motivation to go to higher education')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of grades vs motivation to go to higher education')

# %%
fig, ax = plt.subplots()

sns.distplot(math_data[(math_data.internet == 'yes')]["G3"],ax=ax, label="internet accesss")
sns.distplot(math_data[(math_data.internet == 'no')]['G3'],ax=ax, label="no access")

plt.legend()
plt.title('Distribution of grades vs internet access')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of grades vs internet access')

# %%
fig, ax = plt.subplots()

sns.distplot(math_data[(math_data.activities == 'yes')]["G3"],ax=ax, label="has extra-curriculars")
sns.distplot(math_data[(math_data.activities == 'no')]['G3'],ax=ax, label="no extra-curriculars")

plt.legend()
plt.title('Distribution of grades vs extra-curriculars')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of grades vs extra-curriculars')

# %%
# math_data["walc"] = pd.Categorical(math_data.walc)

# %%
sns.boxplot(y="G3", x="Walc", data = math_data)
# Out:
# <AxesSubplot:xlabel='Walc', ylabel='G3'>

# %%
sns.boxplot(y="G3", x="Dalc", data = math_data)
# Out:
# <AxesSubplot:xlabel='Dalc', ylabel='G3'>

# %%
math_data['wkday_drinks'] = math_data['Dalc'].apply(lambda x:'low' if x==1 else 'non-low')
math_data['wkend_drinks'] = math_data['Walc'].apply(lambda x:'low' if x==1 else 'non-low')

# %%
sns.boxplot(y="G3", x="wkday_drinks", data = math_data)
# Out:
# <AxesSubplot:xlabel='wkday_drinks', ylabel='G3'>

# %%
sns.boxplot(y="G3", x="wkend_drinks", data = math_data)
# Out:
# <AxesSubplot:xlabel='wkend_drinks', ylabel='G3'>

# %%
sns.boxplot(y="G3", x="Medu", data = math_data)
# Out:
# <AxesSubplot:xlabel='Medu', ylabel='G3'>

# %%
sns.boxplot(y="G3", x="Fedu", data = math_data)
# Out:
# <AxesSubplot:xlabel='Fedu', ylabel='G3'>

# %%
math_data['mum_edu'] = math_data['Medu'].apply(lambda x:'college' if x==4 else 'lower')
math_data['pa_edu'] = math_data['Fedu'].apply(lambda x:'college' if x==4 else 'lower')

# %%
sns.boxplot(y="G3", x="mum_edu", data = math_data)
# Out:
# <AxesSubplot:xlabel='mum_edu', ylabel='G3'>

# %%
sns.boxplot(y="G3", x="pa_edu", data = math_data)
# Out:
# <AxesSubplot:xlabel='pa_edu', ylabel='G3'>

# %% [markdown]
# # Modified Plans

# %% [markdown]
# Idea 2: Predict a student's desire for a higher education.
#
# These would also be an interesting question for schools to ask because, realistically, the school would want to give more resources to students willing to pursue a higher education so that those students are accepted to prestigious institutions and promote success for the school. This would raise the school's reputation.

# %% [markdown]
# *Note:* There should be a better way to visualize the features for students pursuing higher education. Barplots like the ones below are ugly and hard to read.

# %%
# Counts of students wanting higher education in portuguese courses
# based on school and reason for attending that school

# Only look at students who answered 'yes' to pursuing a higher education
port_higher_yes = port[port['higher'] == 'yes']
port_higher_yes.groupby(['school', 'reason']).count()[['G3']].plot.bar(legend=None)
plt.title('Counts of school and reason for attending said school')
plt.xlabel('School, Reason for Attending School')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Counts of students wanting higher education in portuguese courses
# based on Fedu and Medu
port_higher_yes.groupby(['Fedu', 'Medu']).count()[['G3']].plot.bar(legend=None)
plt.title('Counts of education level of parents')
plt.xlabel('Father education level, Mother education level')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Counts of students wanting higher education in portuguese courses
# based on nursery school attendance and famsup
port_higher_yes.groupby(['nursery', 'famsup']).count()[['G3']].plot.bar(legend=None)
plt.title('Counts of nursery school attendance and family support')
plt.xlabel('Nursery school attendance, Family support')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Counts of students wanting higher education in portuguese courses
# based on studytime and Dalc
port_higher_yes.groupby(['studytime', 'Dalc']).count()[['G3']].plot.bar(legend=None)
plt.title('Counts of weekly study time and level of weekday alcohol consumption')
plt.xlabel('Weekly study time, Level of weekday alcohol consumption')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# These bar plots aren't that informative. Andrew first used Seaborn categorical plots below, and so I implemented those for my EDA later, as shown below.

# %%
sns.catplot(x='school', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on school")
# Out:
# Text(0.5, 1.0, 'Count of Port. students pursuing a higher education based on school')

# %%
sns.catplot(x='reason', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on reason for attending said school")
# Out:
# Text(0.5, 1.0, 'Count of Port. students pursuing a higher education based on reason for attending said school')

# %%
sns.catplot(x='Fedu', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on father's education")
# Out:
# Text(0.5, 1.0, "Count of Port. students pursuing a higher education based on father's education")

# %%
sns.catplot(x='Medu', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on mother's education")
# Out:
# Text(0.5, 1.0, "Count of Port. students pursuing a higher education based on mother's education")

# %%
sns.catplot(x='Dalc', kind='count', hue = 'higher', data=port)
plt.title("Count of Port. students pursuing a higher education based on weekday alcohol consumption")
# Out:
# Text(0.5, 1.0, 'Count of Port. students pursuing a higher education based on weekday alcohol consumption')

# %%
plt.title("G3 distributions based on desire for higher education")
sns.boxplot(y="higher", x="G3", data = math_data)
# Out:
# <AxesSubplot:title={'center':'G3 distributions based on desire for higher education'}, xlabel='G3', ylabel='higher'>

# %% [markdown]
# It seems that students who want to pursue higher education have a slightly better ditribution of G3 scores.

# %%
sns.catplot(x="higher", kind="count", data=math_data)
plt.title("Math students pursuing higher education")
# Out:
# Text(0.5, 1.0, 'Math students pursuing higher education')

# %%
sns.catplot(x="higher", kind="count", data=port_copy1)
plt.title("Portuguese students pursuing higher education")
# Out:
# Text(0.5, 1.0, 'Portuguese students pursuing higher education')

# %% [markdown]
# Given the count of students wishing to pursue higher education, maybe predicting if a student does not would be more viable.
# <br>
# Plan: group by desire to go to college and look at distributions of various features

# %%
sns.catplot(x="famsize", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="famsup", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="Pstatus", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="address", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="Fedu", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="Medu", kind="count",hue = "higher", data=math_data)

# %%
sns.catplot(x="romantic", kind="count",hue = "higher", data=math_data)

# %%
sns.scatterplot(x = math_data['G3'],y = math_data['health'],hue = math_data['higher'])
# Out:
# <AxesSubplot:xlabel='G3', ylabel='health'>

# %%
sns.scatterplot(x = math_data['G3'],y = math_data['absences'],hue = math_data['higher'])
# Out:
# <AxesSubplot:xlabel='G3', ylabel='absences'>

# %% [markdown]
# # Start Training Models

# %% [markdown]
# We'll start by training linear regression models to predict G3 grades (final grade) based on several features. We're going to construct models for each dataset (math and Portuguese), since there would be duplicate student entries if we were to combine the two datasets.

# %% [markdown]
# ### Data Cleaning

# %%
# Add wk_drinks and wkend_drinks columns to Portuguese dataset
port_copy1['wkday_drinks'] = port_copy1['Dalc'].apply(lambda x:'low' if x==1 else 'non-low')
port_copy1['wkend_drinks'] = port_copy1['Walc'].apply(lambda x:'low' if x==1 else 'non-low')
port_copy1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3 wkday_drinks wkend_drinks
# 0     4    1     1       3         4   0  11  11          low          low
# 1     3    1     1       3         2   9  11  11          low          low
# 2     2    2     3       3         6  12  13  12      non-low      non-low
# 3     2    1     1       5         0  14  14  14          low          low
# 4     2    1     2       5         0  11  13  13          low      non-low
#
# [5 rows x 35 columns]

# %% [markdown]
# ### LinearRegression model for predicting grades on math student dataset

# %%
# Initial features to train models on
grade_features = ['G1', 'G2', 'wkday_drinks', 'wkend_drinks', 'higher']

# Get training X and Y math datasets
math_grade_Xtrain = math_data[grade_features]
math_grade_Xtrain = pd.get_dummies(math_grade_Xtrain)
math_grade_Ytrain = math_data['G3']

# Split training datasets into training and validation data
mg_X_train, mg_X_val, mg_Y_train, mg_Y_val = train_test_split(math_grade_Xtrain, math_grade_Ytrain)

# %%
# Test model on validation data
math_grade_model = LinearRegression()
math_grade_model.fit(mg_X_train, mg_Y_train)
math_grade_score = r2_score(np.array(mg_Y_val), math_grade_model.predict(mg_X_val))
math_grade_score
# Out:
# 0.8974409913356092

# %%
print("The validation accuracy of our LinearRegression model to predict G3 grades for our math student ")
print("dataset was approximately: " + str(round(math_grade_score*100, 2)) + "%.")
# Out:
# The validation accuracy of our LinearRegression model to predict G3 grades for our math student
# dataset was approximately: 89.74%.

# %%
lm = LinearRegression()
scores = cross_val_score(lm, math_grade_Xtrain, math_grade_Ytrain, scoring='r2', cv=5)

# %%
print(np.mean(scores))
# Out:
# 0.8087882163555247

# %%
print("The validation accuracy of our LinearRegression model to predict G3 grades for our math student ")
print("dataset was approximately: " + str(np.mean(scores)*100) + "%.")
# Out:
# The validation accuracy of our LinearRegression model to predict G3 grades for our math student
# dataset was approximately: 80.87882163555247%.

# %% [markdown]
# ### LinearRegression model for predicting grades on Portuguese student dataset

# %%
# Initial features to train model on

# Get training X and Y math datasets
port_grade_Xtrain = port_copy1[grade_features]
port_grade_Xtrain = pd.get_dummies(port_grade_Xtrain)
port_grade_Ytrain = port_copy1['G3']

# Split training datasets into training and validation data
port_X_train, port_X_val, port_Y_train, port_Y_val = train_test_split(port_grade_Xtrain, port_grade_Ytrain)

# %%
# Test model on validation data
port_grade_model = LinearRegression()
port_grade_model.fit(port_X_train, port_Y_train)
port_grade_score = r2_score(np.array(port_Y_val), port_grade_model.predict(port_X_val))
port_grade_score
# Out:
# 0.8309143766726342

# %%
print("The validation accuracy of our LinearRegression model to predict G3 grades for our Portuguese student ")
print("dataset was approximately: " + str(round(port_grade_score*100, 2)) + "%.")
# Out:
# The validation accuracy of our LinearRegression model to predict G3 grades for our Portuguese student
# dataset was approximately: 83.09%.

# %%
lm1 = LinearRegression()
scores1 = cross_val_score(lm1, port_grade_Xtrain, port_grade_Ytrain, scoring='r2', cv=5)

# %%
print(scores1)
# Out:
# [0.81273135 0.75312401 0.8500761  0.88619743 0.81716991]

# %%
print(np.mean(scores1))
# Out:
# 0.8238597599301274

# %%
print("The validation accuracy of our LinearRegression model with 5-fold CV to predict G3 grades for our Portuguese student ")
print("dataset was approximately: " + str(np.mean(scores1)*100) + "%.")
# Out:
# The validation accuracy of our LinearRegression model with 5-fold CV to predict G3 grades for our Portuguese student
# dataset was approximately: 82.38597599301274%.

# %%
#t

# %% [markdown]
# ### Decision tree for predicting 'higher' in math student dataset

# %%
# Initial features to train models on
higher_features = ['G1', 'G2', 'G3', 'wkday_drinks', 'wkend_drinks', 'reason', 'famsup']

# Get training X and Y math datasets
math_higher_Xtrain = math_data[higher_features]
math_higher_Xtrain = pd.get_dummies(math_higher_Xtrain)
math_higher_Ytrain = math_data['higher']

# %%
# Initialize model
math_higher_model = DecisionTreeClassifier()

# %%
# 1000 iterations to see range of our model's accuracy
mh_scores = []
for i in np.arange(1000):
    mh_X_train, mh_X_val, mh_Y_train, mh_Y_val = train_test_split(math_higher_Xtrain, math_higher_Ytrain)
    math_higher_model.fit(mh_X_train, mh_Y_train)
    math_higher_score = accuracy_score(math_higher_model.predict(mh_X_val), np.array(mh_Y_val))
    mh_scores.append(math_higher_score)
display(min(mh_scores), max(mh_scores), np.mean(mh_scores))
# Out:
# 0.797979797979798
# 0.9797979797979798
# 0.9089191919191919

# %%
# Cross-validated classifier
mh_kfold = KFold()
mh_kfold.get_n_splits(math_higher_Xtrain)
mh_kfold_classifier = DecisionTreeClassifier()
for train_index, val_index in mh_kfold.split(math_higher_Xtrain):
    #print("TRAIN:", train_index, "VAL:", val_index)
    mh_Xtrain_kfold, mh_Xval_kfold = math_higher_Xtrain.loc[train_index], math_higher_Xtrain.loc[val_index]
    mh_Ytrain_kfold, mh_Yval_kfold = math_higher_Ytrain.loc[train_index], math_higher_Ytrain.loc[val_index]
    mh_kfold_classifier.fit(mh_Xtrain_kfold, mh_Ytrain_kfold)
    print("Training: " + str(accuracy_score(mh_kfold_classifier.predict(mh_Xtrain_kfold), mh_Ytrain_kfold)))
    print("Validation: " + str(accuracy_score(mh_kfold_classifier.predict(mh_Xval_kfold), mh_Yval_kfold)))

cross_val_score(math_higher_model, math_higher_Xtrain, math_higher_Ytrain, cv=5)
# Out:
# Training: 0.9968354430379747
# Validation: 0.9620253164556962
# Training: 0.9968354430379747
# Validation: 0.9113924050632911
# Training: 0.9968354430379747
# Validation: 0.8354430379746836
# Training: 1.0
# Validation: 0.9113924050632911
# Training: 0.9968354430379747
# Validation: 0.8734177215189873
# array([0.93670886, 0.84810127, 0.87341772, 0.94936709, 0.89873418])

# %% [markdown]
# ### Decision tree for predicting 'higher' with Portuguese student dataset

# %%
# Get training X and Y port datasets
port_higher_Xtrain = port_copy1[higher_features]
port_higher_Xtrain = pd.get_dummies(port_higher_Xtrain)
port_higher_Ytrain = port_copy1['higher']

# %%
# Initialize model
port_higher_model = DecisionTreeClassifier()

# %%
# 1000 iterations to see range of our model's accuracy
ph_scores = []
for i in np.arange(1000):
    ph_X_train, ph_X_val, ph_Y_train, ph_Y_val = train_test_split(port_higher_Xtrain, port_higher_Ytrain)
    port_higher_model.fit(ph_X_train, ph_Y_train)
    port_higher_score = accuracy_score(port_higher_model.predict(ph_X_val), np.array(ph_Y_val))
    ph_scores.append(port_higher_score)
display(min(ph_scores), max(ph_scores), np.mean(ph_scores))
# Out:
# 0.7484662576687117
# 0.9141104294478528
# 0.8357546012269939

# %%
# Cross-validated classifier
ph_kfold = KFold()
ph_kfold.get_n_splits(port_higher_Xtrain)
ph_kfold_classifier = DecisionTreeClassifier()
for train_index, val_index in ph_kfold.split(port_higher_Xtrain):
    #print("TRAIN:", train_index, "VAL:", val_index)
    ph_Xtrain_kfold, ph_Xval_kfold = port_higher_Xtrain.loc[train_index], port_higher_Xtrain.loc[val_index]
    ph_Ytrain_kfold, ph_Yval_kfold = port_higher_Ytrain.loc[train_index], port_higher_Ytrain.loc[val_index]
    ph_kfold_classifier.fit(ph_Xtrain_kfold, ph_Ytrain_kfold)
    print("Training: " + str(accuracy_score(ph_kfold_classifier.predict(ph_Xtrain_kfold), ph_Ytrain_kfold)))
    print("Validation: " + str(accuracy_score(ph_kfold_classifier.predict(ph_Xval_kfold), ph_Yval_kfold)))

cross_val_score(port_higher_model, port_higher_Xtrain, port_higher_Ytrain, cv=5)
# Out:
# Training: 0.9865125240847784
# Validation: 0.9153846153846154
# Training: 0.9922928709055877
# Validation: 0.8
# Training: 0.9865125240847784
# Validation: 0.8615384615384616
# Training: 0.9903660886319846
# Validation: 0.7923076923076923
# Training: 0.9942307692307693
# Validation: 0.7131782945736435
# array([0.86153846, 0.84615385, 0.9       , 0.82307692, 0.72093023])

# %%
# Bagging
ph_scores_bagSets = {}
ph_kscores = []
ph_bag_tree_sets = []
for k in np.arange(15):
    bag_train_predicted = []
    bag_trees = [DecisionTreeClassifier() for i in np.arange(k+1)]
    for tree in bag_trees:
        indices = np.random.choice(np.arange(port_higher_Xtrain.shape[0]), port_higher_Xtrain.shape[0], replace = True)
        x_train_bag = port_higher_Xtrain.loc[indices]
        y_train_bag = port_higher_Ytrain.loc[indices]
        tree.fit(x_train_bag, y_train_bag)
        bag_train_predicted.append(tree.predict(port_higher_Xtrain))
    # print(bag_train_predicted)
    ph_bag_tree_sets.append(bag_trees)
    bag_train_predictions = stats.mode(bag_train_predicted)[0][0]
    ph_kscores.append(accuracy_score(bag_train_predictions, port_higher_Ytrain))
    ph_scores_bagSets[accuracy_score(bag_train_predictions, port_higher_Ytrain)] = k + 1
print(ph_kscores)
# Out:
# [0.9275808936825886, 0.9322033898305084, 0.9568567026194145, 0.9553158705701078, 0.9799691833590138, 0.9738058551617874, 0.9707241910631741, 0.9707241910631741, 0.9830508474576272, 0.9799691833590138, 0.9799691833590138, 0.9830508474576272, 0.9799691833590138, 0.9799691833590138, 0.9815100154083205]

# %% [markdown]
# ## EDA to add features to decision trees

# %%
sns.catplot(x='reason', kind='count', hue='higher', data=port_copy1)
plt.title("Portuguese course students pursuing higher education based on reason for choosing a school")
# Out:
# Text(0.5, 1.0, 'Portuguese course students pursuing higher education based on reason for choosing a school')

# %%
sns.catplot(x='famsup', kind='count', hue='higher', data=port_copy1)
plt.title("Portuguese course students pursuing higher education based on family support")
# Out:
# Text(0.5, 1.0, 'Portuguese course students pursuing higher education based on family support')
